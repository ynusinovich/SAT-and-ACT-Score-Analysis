# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# ## Problem Statement
# The SAT is a college admissions test in competition with the ACT. The new format for the SAT was released in March 2016. This project examines participation rates and total scores for the 2017 and 2018 SAT and ACT, and makes recommendations on how the College Board can improve future SAT participation and scores in the state of West Virginia, which has low SAT scores and low SAT participation.

# %% [markdown]
# ## Executive Summary
#
# This project begins by processing, exploring, and analyzing 2017 and 2018 score and participation data by state for the SAT and ACT. The provided data is combined with outside research to develop recommendations for improving future SAT participation and scores in the state of West Virginia, which has low SAT scores and low SAT participation. Suggestions of additional data to gather are offered.
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %% [markdown]
# Libraries used:
# * act_2017.csv
# * act_2018.csv
# * sat_2017.csv
# * sat_2018.csv

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
# Code:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

act_2017 = pd.read_csv('../data/act_2017.csv')
sat_2017 = pd.read_csv('../data/sat_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
# Code:
print(act_2017.head(10))
print(sat_2017.head(10))
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2
# ...

# %%
# overview = pd.merge(left = act_2017, right = sat_2017, on = "State", how = "outer")
# overview.head()

# %%
# overview.describe()

# %%
# overview.dtypes

# %%
# overview.isnull().sum()

# %%
# overview.info()

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Methods used to look at the data:
# * .head()
# * .describe()
# * .dtypes
# * .isnull().sum()
# * .info()
# * pd.merge(left = act_2017, right = sat_2017, on = "State", how = "outer")
#
# Answer:
# * More urban states tend to take the SAT more
# * More rural states tend to take the ACT more
# * If few people took a test in a state, they got higher scores on that test
# * The overall score on the ACT is an average, and the overall score on the SAT is a total
# * 100% participation on the ACT was more common (17 states) than 100% participation on the SAT (4 states)

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer:
# * The ACT data includes national averages, and the SAT data does not
# * No states or scores are missing

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
# * Wyoming's ACT composite score has an "x" in it
# * The MD SAT math score is a mistake, it's missing the last digit. It should be 524 according to https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/
# * The MD ACT science score is a mistake, it's missing the last digit. It should be 23.2 according to https://www.act.org/content/dam/act/unsecured/documents/cccr2017/P_21_219999_S_S_N00_ACT-GCPR_Maryland.pdf
# * The composite ACT scores are not exactly equal to the average of the individual scores, though they are close
# * The total SAT scores are not exactly equal to the sum of the individual scores, though they are close<br><br>
#
# * The minimum score on the SAT is 200 on each section, or 400 total, and the maximum possible score is 800 on each section, or 1600 total
# * The minimum possible score on the ACT is 1 on each section, or 1 composite, and the maximum possible score is 36 on each section, or 36 composite

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
# code

# act_2017["Composite"] = [i.replace("x","") for i in act_2017["Composite"]]
# act_2017['Composite'] = act_2017['Composite'].str.replace('x', '')
act_2017.loc[51,["Composite"]] = 20.2
# scores should not contain an "x"

act_2017.loc[21,["Science"]] = 23.2
# data source: https://www.act.org/content/dam/act/unsecured/documents/cccr2017/P_21_219999_S_S_N00_ACT-GCPR_Maryland.pdf
# the value in this source makes the average of the "English," "Math," "Reading," and "Science" columns equal to 23.5, which is very close to the "Composite" column value of 23.6, as expected

sat_2017.loc[20,["Math"]] = 524
# data source: https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/
# the value in this source is equal to the "Total" column minus the "Evidence-Based Reading and Writing" column, as expected

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
print(act_2017.dtypes)
print(sat_2017.dtypes)
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
# * The ACT 2017 "Composite" column contains strings, even though it should contain floats, because of the accidental "x" that had been in it
# * The ACT 2017 "Composite" column should be converted to a float
# * The ACT 2017 and SAT 2017 "Participation" columns should have the "%" removed, they should be converted to floats in order to be able to make calculations, and they should be renamed "Participation Percent" to be clear about what the column represents

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
# code

def convert_percent_column_to_float(dataframe, column_name):
    dataframe[column_name] = dataframe[column_name].str.replace('%','')
    dataframe[column_name] = dataframe[column_name].map(int)

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
# code
# These errors have already been fixed in question 4c, the question about fixing errors

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
# code
act_2017["Composite"] = act_2017["Composite"].map(float)
convert_percent_column_to_float(act_2017, "Participation")
convert_percent_column_to_float(sat_2017, "Participation")

print(act_2017)
print(sat_2017)
# Out:
#                    State  Participation  English  Math  Reading  Science  \
# 0               National             60     20.3  20.7     21.4     21.0
# 1                Alabama            100     18.9  18.4     19.7     19.4
# 2                 Alaska             65     18.7  19.8     20.4     19.9
# 3                Arizona             62     18.6  19.8     20.1     19.8
# 4               Arkansas            100     18.9  19.0     19.7     19.5
# 5             California             31     22.5  22.7     23.1     22.2
# 6               Colorado            100     20.1  20.3     21.2     20.9
# 7            Connecticut             31     25.5  24.6     25.6     24.6
# 8               Delaware             18     24.1  23.4     24.8     23.6
# 9   District of Columbia             32     24.4  23.5     24.9     23.5
# 10               Florida             73     19.0  19.4     21.0     19.4
# 11               Georgia             55     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
# code
print(act_2017.dtypes)
print(sat_2017.dtypes)
# Out:
# State             object
# Participation      int64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object
# State                                 object
# Participation                          int64
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
# code

act_2017.rename(columns = {"State": "state",
                           "Participation": "act_2017_participation_%",
                           "English":"act_2017_english",
                           "Math": "act_2017_math",
                           "Reading": "act_2017_reading",
                           "Science": "act_2017_science",
                           "Composite": "act_2017_composite"
                          }, inplace = True)
sat_2017.rename(columns = {"State": "state",
                           "Participation": "sat_2017_participation_%",
                           "Evidence-Based Reading and Writing":"sat_2017_evidence-based_reading_and_writing",
                           "Math":"sat_2017_math",
                           "Total":"sat_2017_total"
                          }, inplace = True)

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# ### Data Dictionary
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|string|ACT 2017 and 2018 and SAT 2017 and 2018|state of the USA where we are looking at test scores|
# |**act_2017_participation_%**|integer|ACT 2017|ACT 2017 participation, percentage of high school students|
# |**act_2017_english**|float|ACT 2017|ACT 2017 English test scores, from 1 to 36|
# |**act_2017_math**|float|ACT 2017|ACT 2017 math test scores, from 1 to 36|
# |**act_2017_reading**|float|ACT 2017|ACT 2017 reading test scores, from 1 to 36|
# |**act_2017_science**|float|ACT 2017|ACT 2017 science test scores, from 1 to 36|
# |**act_2017_composite**|float|ACT 2017|ACT 2017 composite test scores, from 1 to 36|
# |**sat_2017_participation_%**|integer|SAT 2017|SAT 2017 participation, percentage of high school students|
# |**sat_2017_evidence-based_reading_and_writing**|integer|SAT 2017|SAT 2017 English test scores, from 200 to 800|
# |**sat_2017_math**|integer|SAT 2017|SAT 2017 math test scores, from 200 to 800|
# |**sat_2017_total**|integer|SAT 2017|SAT 2017 reading test scores, from 200 to 800|
# |**act_2018_participation_%**|integer|ACT 2018|ACT 2018 participation, percentage of high school students|
# |**act_2018_composite**|float|ACT 2018|ACT 2018 composite test scores, from 1 to 36|
# |**sat_2018_participation_%**|integer|SAT 2018|SAT 2018 participation, percentage of high school students|
# |**sat_2018_evidence-based_reading_and_writing**|integer|SAT 2018|SAT 2018 English test scores, from 200 to 800|
# |**sat_2018_math**|integer|SAT 2018|SAT 2018 math test scores, from 200 to 800|
# |**sat_2018_total**|integer|SAT 2018|SAT 2018 reading test scores, from 200 to 800|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
# code

act_2017.drop(0, inplace = True, axis = 0)
act_2017.index = np.arange(0,len(act_2017["state"]))

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
# code

combined_2017 = pd.merge(left = act_2017, right = sat_2017, on = "state", how = "outer")

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
# code

combined_2017.to_csv('../data/combined_2017.csv', sep = ",", index = False)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %% [markdown]
# Notes:
# * The 2018 data are in a .csv, not a PDF, so I will follow the same steps as I did for the 2017 data
# * The ACT 2018 data has an extra "Maine" row
# * The ACT 2018 data has "District of Columbia" written as "district of columbia"
# * The ACT 2018 data is missing scores by subject, and only has "Composite" scores

# %%
act_2018 = pd.read_csv('../data/act_2018.csv')
sat_2018 = pd.read_csv('../data/sat_2018.csv')

act_2018.loc[8,["State"]] = "District of Columbia"

convert_percent_column_to_float(act_2018, "Participation")
convert_percent_column_to_float(sat_2018, "Participation")


act_2018.rename(columns = {"State": "state",
                           "Participation": "act_2018_participation_%",
                           "Composite": "act_2018_composite"
                          }, inplace = True)
sat_2018.rename(columns = {"State": "state",
                           "Participation": "sat_2018_participation_%",
                           "Evidence-Based Reading and Writing":"sat_2018_evidence-based_reading_and_writing",
                           "Math":"sat_2018_math",
                           "Total":"sat_2018_total"
                          }, inplace = True)

act_2018.drop(19, inplace = True, axis = 0)
act_2018.index = np.arange(0,len(act_2018["state"]))

# %%
combined_2018 = pd.merge(left = act_2018, right = sat_2018, on = "state", how = "outer")
combined_2018.to_csv('../data/combined_2018.csv', sep = ",", index = False)

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
final = pd.merge(left = combined_2017, right = combined_2018, on = "state", how = "outer")
final.to_csv('../data/final.csv', sep = ",", index = False)

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
# code

final.describe().T
# Out:
#                                              count         mean        std  \
# act_2017_participation_%                      51.0    65.254902  32.140842
# act_2017_english                              51.0    20.931373   2.353677
# act_2017_math                                 51.0    21.182353   1.981989
# act_2017_reading                              51.0    22.013725   2.067271
# act_2017_science                              51.0    21.450980   1.739353
# act_2017_composite                            51.0    21.519608   2.020695
# sat_2017_participation_%                      51.0    39.803922  35.276632
# sat_2017_evidence-based_reading_and_writing   51.0   569.117647  45.666901
# sat_2017_math                                 51.0   556.882353  47.121395
# sat_2017_total                                51.0  1126.098039  92.494812
# act_2018_participation_%                      51.0    61.725490  34.037085
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
# code

def stddevcalc(column):
    n = len(column)
    mu = np.mean(column)
    sumofsquares = 0
    for i in column:
        sumofsquares = sumofsquares + (i-mu)**2
    stddev = (1/n * sumofsquares)**(1/2)
    return stddev

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
# code

sd = {column:stddevcalc(final[column]) for column in final.columns.tolist() if column != "state"}
sd
# Out:
# {'act_2017_participation_%': 31.824175751231806,
#  'act_2017_english': 2.3304876369363363,
#  'act_2017_math': 1.9624620273436781,
#  'act_2017_reading': 2.0469029314842646,
#  'act_2017_science': 1.7222161451443676,
#  'act_2017_composite': 2.000786081581989,
#  'sat_2017_participation_%': 34.92907076664508,
#  'sat_2017_evidence-based_reading_and_writing': 45.21697020437866,
#  'sat_2017_math': 46.65713364485503,
#  'sat_2017_total': 91.58351056778743,
#  'act_2018_participation_%': 33.70173582041031,
#  'act_2018_composite': 2.090779082141178,
#  'sat_2018_participation_%': 36.946619223539415,
#  'sat_2018_evidence-based_reading_and_writing': 47.03460978357609,
#  'sat_2018_math': 47.30194550378352,
#  'sat_2018_total': 93.22742384464433}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %%
final.describe()
# Out:
#        act_2017_participation_%  act_2017_english  act_2017_math  \
# count                 51.000000         51.000000      51.000000
# mean                  65.254902         20.931373      21.182353
# std                   32.140842          2.353677       1.981989
# min                    8.000000         16.300000      18.000000
# 25%                   31.000000         19.000000      19.400000
# 50%                   69.000000         20.700000      20.900000
# 75%                  100.000000         23.300000      23.100000
# max                  100.000000         25.500000      25.300000
#
#        act_2017_reading  act_2017_science  act_2017_composite  \
# count         51.000000         51.000000           51.000000
# mean          22.013725         21.450980           21.519608
# std            2.067271          1.739353            2.020695
# min           18.100000         18.200000           17.800000
# 25%           20.450000         19.950000           19.800000
# ...

# %%
sd_numpy = {column:np.std(final[column]) for column in final.columns.tolist() if column != "state"}
sd_numpy
# Out:
# {'act_2017_participation_%': 31.824175751231806,
#  'act_2017_english': 2.3304876369363363,
#  'act_2017_math': 1.9624620273436781,
#  'act_2017_reading': 2.0469029314842646,
#  'act_2017_science': 1.7222161451443676,
#  'act_2017_composite': 2.000786081581989,
#  'sat_2017_participation_%': 34.92907076664508,
#  'sat_2017_evidence-based_reading_and_writing': 45.21697020437866,
#  'sat_2017_math': 46.65713364485503,
#  'sat_2017_total': 91.58351056778743,
#  'act_2018_participation_%': 33.70173582041031,
#  'act_2018_composite': 2.090779082141178,
#  'sat_2018_participation_%': 36.946619223539415,
#  'sat_2018_evidence-based_reading_and_writing': 47.03460978357609,
#  'sat_2018_math': 47.30194550378352,
#  'sat_2018_total': 93.22742384464433}

# %% [markdown]
# Answer:
# * For the .describe() method, the first two digits of the standard deviations matched, but not after that
# * For the np.std() method, my calculations matched exactly

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# code

print(final.loc[:,["state","sat_2017_participation_%","sat_2017_total"]].sort_values("sat_2017_participation_%", ascending = False).head())
print(final.loc[:,["state","sat_2017_participation_%","sat_2017_total"]].sort_values("sat_2017_participation_%", ascending = True).head())

print(final.loc[:,["state","sat_2018_participation_%","sat_2018_total"]].sort_values("sat_2018_participation_%", ascending = False).head())
print(final.loc[:,["state","sat_2018_participation_%","sat_2018_total"]].sort_values("sat_2018_participation_%", ascending = True).head())

print(final.loc[:,["state","act_2017_participation_%","act_2017_composite"]].sort_values("act_2017_participation_%", ascending = False).head(20))
print(final.loc[:,["state","act_2017_participation_%","act_2017_composite"]].sort_values("act_2017_participation_%", ascending = True).head())

print(final.loc[:,["state","act_2018_participation_%","act_2018_composite"]].sort_values("act_2018_participation_%", ascending = False).head(20))
print(final.loc[:,["state","act_2018_participation_%","act_2018_composite"]].sort_values("act_2018_participation_%", ascending = True).head())
# Out:
#                    state  sat_2017_participation_%  sat_2017_total
# 8   District of Columbia                       100             950
# 22              Michigan                       100            1005
# 6            Connecticut                       100            1041
# 7               Delaware                       100             996
# 29         New Hampshire                        96            1052
#            state  sat_2017_participation_%  sat_2017_total
# 34  North Dakota                         2            1256
# 24   Mississippi                         2            1242
# 15          Iowa                         2            1275
# 25      Missouri                         3            1271
# 44          Utah                         3            1238
#           state  sat_2018_participation_%  sat_2018_total
# 5      Colorado                       100            1025
# 6   Connecticut                       100            1053
# ...

# %%
# code

print(final.loc[:,["state","sat_2017_participation_%","sat_2017_total"]].sort_values("sat_2017_total", ascending = False).head())
print(final.loc[:,["state","sat_2017_participation_%","sat_2017_total"]].sort_values("sat_2017_total", ascending = True).head())

print(final.loc[:,["state","sat_2018_participation_%","sat_2018_total"]].sort_values("sat_2018_total", ascending = False).head())
print(final.loc[:,["state","sat_2018_participation_%","sat_2018_total"]].sort_values("sat_2018_total", ascending = True).head())

print(final.loc[:,["state","act_2017_participation_%","act_2017_composite"]].sort_values("act_2017_composite", ascending = False).head(20))
print(final.loc[:,["state","act_2017_participation_%","act_2017_composite"]].sort_values("act_2017_composite", ascending = True).head())

print(final.loc[:,["state","act_2018_participation_%","act_2018_composite"]].sort_values("act_2018_composite", ascending = False).head(20))
print(final.loc[:,["state","act_2018_participation_%","act_2018_composite"]].sort_values("act_2018_composite", ascending = True).head())
# Out:
#         state  sat_2017_participation_%  sat_2017_total
# 23  Minnesota                         3            1295
# 49  Wisconsin                         3            1291
# 15       Iowa                         2            1275
# 25   Missouri                         3            1271
# 16     Kansas                         4            1260
#                    state  sat_2017_participation_%  sat_2017_total
# 8   District of Columbia                       100             950
# 7               Delaware                       100             996
# 12                 Idaho                        93            1005
# 22              Michigan                       100            1005
# 19                 Maine                        95            1012
#            state  sat_2018_participation_%  sat_2018_total
# 23     Minnesota                         4            1298
# 49     Wisconsin                         3            1294
# ...

# %%
final.loc[((final["sat_2017_participation_%"] == 100) & (final["sat_2018_participation_%"] != 100)) | ((final["sat_2018_participation_%"] == 100) & (final["sat_2017_participation_%"] != 100)), :]
# Out:
#                    state  act_2017_participation_%  act_2017_english  \
# 5               Colorado                       100              20.1
# 8   District of Columbia                        32              24.4
# 12                 Idaho                        38              21.9
#
#     act_2017_math  act_2017_reading  act_2017_science  act_2017_composite  \
# 5            20.3              21.2              20.9                20.8
# 8            23.5              24.9              23.5                24.2
# 12           21.8              23.0              22.1                22.3
#
#     sat_2017_participation_%  sat_2017_evidence-based_reading_and_writing  \
# 5                         11                                          606
# 8                        100                                          482
# 12                        93                                          513
#
#     sat_2017_math  sat_2017_total  act_2018_participation_%  \
# ...

# %%
final.loc[((final["act_2017_participation_%"] == 100) & (final["act_2018_participation_%"] != 100)) | ((final["act_2018_participation_%"] == 100) & (final["act_2017_participation_%"] != 100)), :]
# Out:
#         state  act_2017_participation_%  act_2017_english  act_2017_math  \
# 5    Colorado                       100              20.1           20.3
# 23  Minnesota                       100              20.4           21.5
# 27   Nebraska                        84              20.9           20.9
# 35       Ohio                        75              21.2           21.6
#
#     act_2017_reading  act_2017_science  act_2017_composite  \
# 5               21.2              20.9                20.8
# 23              21.8              21.6                21.5
# 27              21.9              21.5                21.4
# 35              22.5              22.0                22.0
#
#     sat_2017_participation_%  sat_2017_evidence-based_reading_and_writing  \
# 5                         11                                          606
# 23                         3                                          644
# 27                         3                                          629
# ...

# %%
final.loc[((final["sat_2017_participation_%"] >= 50) & (final["act_2017_participation_%"] >= 50)) | ((final["sat_2018_participation_%"] >= 50) & (final["act_2018_participation_%"] >= 50)), :]
# Out:
#              state  act_2017_participation_%  act_2017_english  act_2017_math  \
# 9          Florida                        73              19.0           19.4
# 10         Georgia                        55              21.0           20.9
# 11          Hawaii                        90              17.8           19.2
# 33  North Carolina                       100              17.8           19.3
# 40  South Carolina                       100              17.5           18.6
#
#     act_2017_reading  act_2017_science  act_2017_composite  \
# 9               21.0              19.4                19.8
# 10              22.0              21.3                21.4
# 11              19.2              19.3                19.0
# 33              19.6              19.3                19.1
# 40              19.1              18.9                18.7
#
#     sat_2017_participation_%  sat_2017_evidence-based_reading_and_writing  \
# ...

# %% [markdown]
# Notable state results:
# * West Virginia had both low SAT scores (999 total) and low SAT participation (28%)
# * Colorado increased SAT participation from 11% in 2017 to 100% in 2018
# * Georgia had over 50% participation in both the ACT and the SAT in both 2017 and 2018, and the SAT participation increased from 61% in 2017 to 70% in 2018

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize = (15,15))
plt.title("Correlations Between Scores and Participation Rates By State for the 2017 and 2018 SAT and ACT")
sns.heatmap(final.corr(), annot = True)

# %% [markdown]
# Notes:
# * Higher participation rates on one test correlate with lower participation rates on the other test
# * Higher scores on one test correlate with lower scores on the other test
# * Higher participation rates on one test on the first year correlate with higher participation rates on that test on the next year
# * Higher scores on one section of a test correlated with higher scores on another section of a test

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
np.isnan(5)
# Out:
# False

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, x_label, x_min = np.nan, x_max = np.nan, x_step = np.nan):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows = nrows, ncols = 2, figsize = (15,15)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # Feel free to add more settings
#         Set titles, labels, etc here for each subplot
        plt.subplot(ax[i])
        if np.isnan(x_min) or np.isnan(x_max) or np.isnan(x_step):
            plt.xticks(np.arange(round(min(dataframe[column])),round(max(dataframe[column]))+1,round((max(dataframe[column])-min(dataframe[column]))/10)))
        else:
            plt.xticks(np.arange(x_min,x_max+1,x_step))
        plt.title(list_of_titles[i])
        plt.xlabel(x_label)
        plt.ylabel("number of states")

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# code

participation_col = ["act_2017_participation_%","sat_2017_participation_%","act_2018_participation_%","sat_2018_participation_%"]
participation_titles = ["Participation % in the 2017 ACT","Participation % in the 2017 SAT","Participation % in the 2018 ACT","Participation % in the 2018 SAT"]
participation_x_label = "test participation %"
participation_min = 0
participation_max = 100
participation_step = 10
subplot_histograms(final,participation_col,participation_titles,participation_x_label,participation_min,participation_max,participation_step)

# %% [markdown]
# Notes:
# * 2018 SAT participation was higher than 2017 SAT participation
# * 2018 ACT participation was lower than 2017 ACT participation
# * Fewer states had no ACT participation than no SAT participation
# * Fewer states had full SAT participation than full SAT participation

# %%
math_col = ["act_2017_math","sat_2017_math","sat_2018_math"]
math_titles = ["Math Scores in the 2017 ACT","Math Scores in the 2017 SAT","Math Scores in the 2018 SAT"]
math_x_label = "math score"
subplot_histograms(final,math_col,math_titles,math_x_label)

# %% [markdown]
# Notes:
# * The 2018 SAT had lower math scores than the 2017 SAT
# * The 2017 ACT math scores look more left-skewed than the 2017 SAT math scores

# %%
reading_col = ["act_2017_english","act_2017_reading","sat_2017_evidence-based_reading_and_writing","sat_2018_evidence-based_reading_and_writing"]
reading_titles = ["English Scores in the 2017 ACT","Reading Scores in the 2017 ACT","Reading and Writing Scores in the 2017 SAT","Reading and Writing Scores in the 2018 SAT"]
reading_x_label = "reading/verbal score"
subplot_histograms(final,reading_col,reading_titles,reading_x_label)

# %% [markdown]
# Notes:
# * The SAT appears to have a more bimodal distribution in reading and writing scores than the ACT has in English or reading scores
# * 2018 SAT reading and writing scores look higher than 2017 SAT reading and writing scores

# %%
total_col = ["act_2017_composite","act_2018_composite","sat_2017_total","sat_2018_total"]
total_titles = ["Composite Scores in the 2017 ACT","Composite Scores in the 2017 ACT","Total Scores in the 2017 SAT","Total Scores in the 2018 SAT"]
total_x_label = "composite/total score"
subplot_histograms(final,total_col,total_titles,total_x_label)

# %% [markdown]
# Notes:
#
# The SAT appears to have a more bimodal distribution in reading and writing scores than the ACT has in English or reading scores
# 2018 SAT reading and writing scores look higher than 2017 SAT reading and writing scores

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# code

def comparison_scatter_plot(dataframe,x_col,y_col,x_lab,y_lab,title):
    plt.figure(figsize = (10, 10))
    plt.scatter(dataframe[x_col], dataframe[y_col])
    plt.title(title)
    plt.xlabel(x_lab, fontsize = 10)
    plt.ylabel(y_lab, fontsize = 10)

# %%
comparison_scatter_plot(final,"act_2017_math","sat_2017_math","ACT 2017 math scores","SAT 2017 math scores","ACT vs. SAT Math Scores for 2017")

# %% [markdown]
# Notes:
# * ACT 2017 math scores had a weak negative correlation to SAT 2017 math scores

# %%
comparison_scatter_plot(final,"act_2017_english","sat_2017_evidence-based_reading_and_writing","ACT 2017 English scores","SAT 2017 evidence-based reading and writing scores","ACT English Scores vs. SAT Evidence-Based Reading and Writing Scores for 2017")

# %% [markdown]
# Notes:
# * ACT 2017 English scores had a weak negative correlation to SAT 2017 evidence-based reading and writing scores

# %%
comparison_scatter_plot(final,"act_2017_reading","sat_2017_evidence-based_reading_and_writing","ACT 2017 reading scores","SAT 2017 evidence-based reading and writing scores","ACT Reading Scores vs. SAT Evidence-Based Reading and Writing Scores for 2017")

# %% [markdown]
# Notes:
# * ACT 2017 reading scores had a weak negative correlation to SAT 2017 evidence-based reading and writing scores

# %%
comparison_scatter_plot(final,"act_2017_composite","sat_2017_total","ACT 2017 composite scores","SAT 2017 total scores","ACT Composite Scores vs. SAT Total Scores for 2017")

# %% [markdown]
# Notes:
# * ACT 2017 composite scores had a weak negative correlation to SAT 2017 total scores

# %%
comparison_scatter_plot(final,"sat_2017_total","sat_2018_total","SAT 2017 total scores","SAT 2018 total scores","SAT Total Scores for 2017 vs. 2018")

# %% [markdown]
# Notes:
# * SAT 2017 total scores had a positive correlation to SAT 2018 total scores

# %%
comparison_scatter_plot(final,"act_2017_composite","act_2018_composite","ACT 2017 composite scores","ACT 2018 composite scores","ACT Composite Scores for 2017 vs. 2018")

# %% [markdown]
# Notes:
# * ACT 2017 composite scores had a positive correlation to ACT 2018 composite scores

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
plt.figure(figsize = (25,25))
plt.title('Spread in Variables Across ACT and SAT (2017/2018)', fontsize = 25)
plt.ylabel('Frequency', fontsize = 20)
plt.xlabel('ACT and SAT Variables for 2017 and 2018', fontsize = 20)
sns.boxplot(data = final[["act_2017_english", "act_2017_math", "act_2017_reading", "act_2017_science", "act_2017_composite","act_2018_composite"]], orient = "h")

# %% [markdown]
# Notes:
# * In the 2017 ACT, English scores had the most variability and science scores had the least
# * ACT composite score variability went up in 2018, and the median score went down

# %%
plt.figure(figsize = (25,25))
plt.title('Spread in Variables Across ACT and SAT (2017/2018)', fontsize = 25)
plt.ylabel('Frequency', fontsize = 20)
plt.xlabel('ACT and SAT Variables for 2017 and 2018', fontsize = 20)
sns.boxplot(data = final[["act_2017_participation_%", "act_2018_participation_%"]], orient = "h")

# %% [markdown]
# Notes:
# * Median participation rates for the ACT went down slighlty in 2018 compared to 2017

# %%
plt.figure(figsize = (25,25))
plt.title('Spread in Variables Across ACT and SAT (2017/2018)', fontsize = 25)
plt.ylabel('Frequency', fontsize = 20)
plt.xlabel('ACT and SAT Variables for 2017 and 2018', fontsize = 20)
sns.boxplot(data = final[["sat_2017_evidence-based_reading_and_writing","sat_2017_math", "sat_2017_total","sat_2018_evidence-based_reading_and_writing","sat_2018_math", "sat_2018_total"]], orient = "h")

# %% [markdown]
# Notes:
# * The SAT math tests had lower median and higher variability than the evidence-based reading and writing tests
# * The median SAT scores in 2018 were lower than in 2017

# %%
plt.figure(figsize = (25,25))
plt.title('Spread in Variables Across ACT and SAT (2017/2018)', fontsize = 25)
plt.ylabel('Frequency', fontsize = 20)
plt.xlabel('ACT and SAT Variables for 2017 and 2018', fontsize = 20)
sns.boxplot(data = final[["sat_2017_participation_%", "sat_2018_participation_%"]], orient = "h")

# %% [markdown]
# Notes:
# * Median SAT participation increased in 2018 compared to 2017

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
plt.figure(figsize = (10, 10))

sat_2017_part_vals = final["sat_2017_participation_%"]
sat_2018_part_vals = final["sat_2018_participation_%"]

states = final["state"].tolist()

width = 0.35

plt.barh(states, sat_2017_part_vals, width)
plt.barh(states, sat_2018_part_vals, width, left = sat_2017_part_vals)

plt.xlabel('total participation % over 2 years')
plt.title('SAT Participation % by State 2017 and 2018')
plt.yticks(states)
plt.xticks(np.arange(0, 201, 10))
plt.legend(("SAT 2017 Participation %", "SAT 2018 Participation %"))

plt.show()

# %%
final.plot(x = "state", y = ["sat_2017_participation_%", "sat_2018_participation_%"], kind = "bar", figsize = (20, 10), title = "SAT Participation % by State, 2017 and 2018")
plt.xlabel("State")
plt.ylabel("Participation %")
plt.legend(("SAT 2017 Participation %", "SAT 2018 Participation %"))

# %% [markdown]
# Notes:
# * Florida had a significant decrease in SAT participation from 2017 to 2018
# * West Virginia, Illinois, and Colorado had a significant increase in SAT participation from 2017 to 2018
# * (See code below)

# %%
final.loc[(final["sat_2018_participation_%"] >= 2 * final["sat_2017_participation_%"]),["state","sat_2017_participation_%","sat_2018_participation_%"]]
# Out:
#             state  sat_2017_participation_%  sat_2018_participation_%
# 5        Colorado                        11                       100
# 13       Illinois                         9                        99
# 48  West Virginia                        14                        28

# %%
final.loc[(final["sat_2017_participation_%"] >= 1.4 * final["sat_2018_participation_%"]),["state","sat_2017_participation_%","sat_2018_participation_%"]]
# Out:
#      state  sat_2017_participation_%  sat_2018_participation_%
# 9  Florida                        83                        56

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %%
# I'm not doing this one since I don't know Tableau

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
final.describe()
final.describe().loc[:,["sat_2017_total","sat_2018_total"]]
# Out:
#        sat_2017_total  sat_2018_total
# count       51.000000       51.000000
# mean      1126.098039     1120.019608
# std         92.494812       94.155083
# min        950.000000      977.000000
# 25%       1055.500000     1057.500000
# 50%       1107.000000     1098.000000
# 75%       1212.000000     1204.000000
# max       1295.000000     1298.000000

# %% [markdown]
# Answers:
# * ACT participation % standard deviation increased from 2017 to 2018
# * ACT participation % mean and median decreased from 2017 to 2018
# * SAT participation % standard deviation increased from 2017 to 2018
# * SAT participation % mean and median increased from 2017 to 2018
# * ACT composite standard deviation increased from 2017 to 2018
# * ACT composite mean and median decreased from 2017 to 2018
# * SAT total standard deviation increased from 2017 to 2018
# * SAT total mean and median decreased from 2017 to 2018

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:
# * Based on the histograms and boxplots above, none of the data in this dataset is normally distributed

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:
# * Based on the histograms and boxplots above, every column of data appears to be bimodal, or close to it, rather than normal
# * Since the data aren't normal, we can't make estimates for unknown states
# * Since the 2017 and 2018 data are highly correlated, you can use 2018 data to estimate 2019 data, though this is not related to the distributions

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:
# * SAT and ACT participation rates can be compared
# * Most students in a state take one test or the other, based on what other students take, what's legally mandated, and what they feel prepared for
# * Higher participation in one test correlated with lower participation in another
# * Improvement in SAT participation would result in decreased ACT participation

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:
# * The ACT and SAT math, reading, English, and evidence-based reading and writing scores can't be compared
# * The math, reading, English, and evidence-based reading and writing portions of these tests are designed by different organizations, and they don't necessarily have the same testing goals

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# I'm not doing this one since we have not yet discussed this in class

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# * West Virginia had both low SAT scores (999 total) and low SAT participation (28%)
# * Colorado increased SAT participation from 11% in 2017 to 100% in 2018
# * Georgia had over 50% participation in both the ACT and the SAT in both 2017 and 2018, and the SAT participation increased from 61% in 2017 to 70% in 2018
# * Florida had a significant decrease in SAT participation from 2017 to 2018 (>1.4x)
# * West Virginia and Illinois had a significant increase in SAT participation from 2017 to 2018 (>2x)

# %% [markdown]
# * Colorado had 100% SAT participation in 2018 because the state made the test mandatory and free
# * https://www.testive.com/colorado-sat-change-2017/<br><br>
#
# * Illinois had 99% SAT participation in 2018 because the state made the test mandatory and free
# * https://www.noodlepros.com/blog/2017/04/05/the-problem-with-illinois-new-mandatory-sat/<br><br>
#
# * DC had the following SAT participation intiatives:
#     * PSAT administered to all grade 9 and 11 students
#     * SAT School Day  for grade 11 students
#     * Free SAT Exam for all grade 11 students, which goes beyond the common practice of offering fee‐waivers for students who qualify for free‐ or reduced‐price lunch
#     * Free test preparation available from the College Board, Washington D.C.'s Individual Graduation Portfolio, Kaplan, and school‐managed courses
# * https://www.hanoverresearch.com/media/Best-Practices-to-Increase-SAT-Participation-1.pdf<br><br>
#
# * Idaho, Delaware, Maine and the District of Columbia participated in the SAT School Day in 2018, which the College Board launched in an effort to increase access for students who historically take the test at lower rates, including low-income and first-generation students, students who work on the weekends, have family obligations or have trouble accessing transportation to testing centers
# * https://www.usnews.com/news/education-news/articles/2019-09-24/more-students-are-taking-the-sat-than-ever-before<br><br>
#
# * The College Board redesigned the SAT in 2016 to make it more straightforward and connected to classroom learning. Some of the changes reflected in the new SAT include removing the guessing penalty, focusing on words students will use in college and careers, and making the essay optional
# * https://www.ajc.com/blog/get-schooled/state-scores-improve-old-sat-too-early-tell-how-georgia-fared-new-version/8wbwe9RfF4ibFWhca10xMO/

# %%
# states that had 100% SAT participation in 2017 or 2018
final.loc[((final["sat_2017_participation_%"] == 100) | (final["sat_2018_participation_%"] == 100)) | ((final["sat_2018_participation_%"] == 100) & (final["sat_2017_participation_%"] != 100)), :]
# Out:
#                    state  act_2017_participation_%  act_2017_english  \
# 5               Colorado                       100              20.1
# 6            Connecticut                        31              25.5
# 7               Delaware                        18              24.1
# 8   District of Columbia                        32              24.4
# 12                 Idaho                        38              21.9
# 22              Michigan                        29              24.1
#
#     act_2017_math  act_2017_reading  act_2017_science  act_2017_composite  \
# 5            20.3              21.2              20.9                20.8
# 6            24.6              25.6              24.6                25.2
# 7            23.4              24.8              23.6                24.1
# 8            23.5              24.9              23.5                24.2
# 12           21.8              23.0              22.1                22.3
# ...

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# * I would like to focus on West Virginia since it had low scores and participation<br><br>
#
# * Recommendations:
#     * Mandating the completion of the SAT for all high school students
#     * Fee waivers from the College Board cover 100% of test registration costs
#     * “SAT School Day” generally includes a free SAT exam offered during the school day to make student participation as convenient as possible
#     * Increasing student and family awareness of college accessibility, especially among racial and ethnic minorities, English language learners, and economically disadvantaged students
#     * Increasing access to the PSAT
#     * Have school district offer for-credit SAT preparation course
#     * Free test preparation available from the College Board and the schools
#     * SAT question of the day contest<br><br>
#
# * Additional useful data:
#     * Have any of these programs been implemented?
#     * What are the participation rates by income and race?
#     * How do West Virginia schools fare in participation and scores for other standardized tests that people take in addition to the SAT?
#         * AP
#         * SAT 2

# %%
plt.figure(figsize=(10, 10))

plt.bar(["2017 SAT","2018 SAT"], [final.loc[48,"sat_2017_participation_%"], final.loc[48,"sat_2018_participation_%"]], width = 0.5)
plt.ylabel("Participation %")
plt.yticks(np.arange(0,31,5))
plt.title("West Virginia SAT % Participation Increase from 2017 to 2018")
# Out:
# Text(0.5, 1.0, 'West Virginia SAT % Participation Increase from 2017 to 2018')

# %%
plt.figure(figsize=(10, 10))

plt.bar(["2017 SAT","2018 SAT"], [final.loc[48,"sat_2017_total"], final.loc[48,"sat_2018_total"]], width = 0.5)
plt.ylabel("Total Score")
plt.yticks(np.arange(0,1200,100))
plt.title("West Virginia SAT Total Score Decrease from 2017 to 2018")
# Out:
# Text(0.5, 1.0, 'West Virginia SAT Total Score Decrease from 2017 to 2018')

# %%
final.loc[(final["sat_2017_participation_%"] > final["sat_2018_participation_%"]), :]
# Out:
#                    state  act_2017_participation_%  act_2017_english  \
# 2                Arizona                        62              18.6
# 8   District of Columbia                        32              24.4
# 9                Florida                        73              19.0
# 28                Nevada                       100              16.3
#
#     act_2017_math  act_2017_reading  act_2017_science  act_2017_composite  \
# 2            19.8              20.1              19.8                19.7
# 8            23.5              24.9              23.5                24.2
# 9            19.4              21.0              19.4                19.8
# 28           18.0              18.1              18.2                17.8
#
#     sat_2017_participation_%  sat_2017_evidence-based_reading_and_writing  \
# 2                         30                                          563
# 8                        100                                          482
# ...
